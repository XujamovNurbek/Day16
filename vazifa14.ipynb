# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_csv("vazifa14.csv")
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
pd.get_dummies(df)
# Out:
#       age     bmi  children      charges  sex_female  sex_male  smoker_no  \
# 0      19  27.900         0  16884.92400        True     False      False
# 1      18  33.770         1   1725.55230       False      True       True
# 2      28  33.000         3   4449.46200       False      True       True
# 3      33  22.705         0  21984.47061       False      True       True
# 4      32  28.880         0   3866.85520       False      True       True
# ...   ...     ...       ...          ...         ...       ...        ...
# 1333   50  30.970         3  10600.54830       False      True       True
# 1334   18  31.920         0   2205.98080        True     False       True
# 1335   18  36.850         0   1629.83350        True     False       True
# 1336   21  25.800         0   2007.94500        True     False       True
# 1337   61  29.070         0  29141.36030        True     False      False
#
#       smoker_yes  region_northeast  region_northwest  region_southeast  \
# ...

# %%
pd.get_dummies(df, dtype=int)
# Out:
#       age     bmi  children      charges  sex_female  sex_male  smoker_no  \
# 0      19  27.900         0  16884.92400           1         0          0
# 1      18  33.770         1   1725.55230           0         1          1
# 2      28  33.000         3   4449.46200           0         1          1
# 3      33  22.705         0  21984.47061           0         1          1
# 4      32  28.880         0   3866.85520           0         1          1
# ...   ...     ...       ...          ...         ...       ...        ...
# 1333   50  30.970         3  10600.54830           0         1          1
# 1334   18  31.920         0   2205.98080           1         0          1
# 1335   18  36.850         0   1629.83350           1         0          1
# 1336   21  25.800         0   2007.94500           1         0          1
# 1337   61  29.070         0  29141.36030           1         0          0
#
#       smoker_yes  region_northeast  region_northwest  region_southeast  \
# ...

# %%
pd.get_dummies(df, columns=["sex"], dtype=int, drop_first=True)
# Out:
#       age     bmi  children smoker     region      charges  sex_male
# 0      19  27.900         0    yes  southwest  16884.92400         0
# 1      18  33.770         1     no  southeast   1725.55230         1
# 2      28  33.000         3     no  southeast   4449.46200         1
# 3      33  22.705         0     no  northwest  21984.47061         1
# 4      32  28.880         0     no  northwest   3866.85520         1
# ...   ...     ...       ...    ...        ...          ...       ...
# 1333   50  30.970         3     no  northwest  10600.54830         1
# 1334   18  31.920         0     no  northeast   2205.98080         0
# 1335   18  36.850         0     no  southeast   1629.83350         0
# 1336   21  25.800         0     no  southwest   2007.94500         0
# 1337   61  29.070         0    yes  northwest  29141.36030         0
#
# [1338 rows x 7 columns]

# %%
pd.get_dummies(df, columns=["smoker"], dtype=int, drop_first=True)
# Out:
#       age     sex     bmi  children     region      charges  smoker_yes
# 0      19  female  27.900         0  southwest  16884.92400           1
# 1      18    male  33.770         1  southeast   1725.55230           0
# 2      28    male  33.000         3  southeast   4449.46200           0
# 3      33    male  22.705         0  northwest  21984.47061           0
# 4      32    male  28.880         0  northwest   3866.85520           0
# ...   ...     ...     ...       ...        ...          ...         ...
# 1333   50    male  30.970         3  northwest  10600.54830           0
# 1334   18  female  31.920         0  northeast   2205.98080           0
# 1335   18  female  36.850         0  southeast   1629.83350           0
# 1336   21  female  25.800         0  southwest   2007.94500           0
# 1337   61  female  29.070         0  northwest  29141.36030           1
#
# [1338 rows x 7 columns]

# %%
pd.get_dummies(df, columns=["smoker"], dtype=int, drop_first=True, prefix="smoker")
# Out:
#       age     sex     bmi  children     region      charges  smoker_yes
# 0      19  female  27.900         0  southwest  16884.92400           1
# 1      18    male  33.770         1  southeast   1725.55230           0
# 2      28    male  33.000         3  southeast   4449.46200           0
# 3      33    male  22.705         0  northwest  21984.47061           0
# 4      32    male  28.880         0  northwest   3866.85520           0
# ...   ...     ...     ...       ...        ...          ...         ...
# 1333   50    male  30.970         3  northwest  10600.54830           0
# 1334   18  female  31.920         0  northeast   2205.98080           0
# 1335   18  female  36.850         0  southeast   1629.83350           0
# 1336   21  female  25.800         0  southwest   2007.94500           0
# 1337   61  female  29.070         0  northwest  29141.36030           1
#
# [1338 rows x 7 columns]

# %%
pd.get_dummies(df, columns=["smoker"], dtype=int, drop_first=True, prefix_sep="")
# Out:
#       age     sex     bmi  children     region      charges  smokeryes
# 0      19  female  27.900         0  southwest  16884.92400          1
# 1      18    male  33.770         1  southeast   1725.55230          0
# 2      28    male  33.000         3  southeast   4449.46200          0
# 3      33    male  22.705         0  northwest  21984.47061          0
# 4      32    male  28.880         0  northwest   3866.85520          0
# ...   ...     ...     ...       ...        ...          ...        ...
# 1333   50    male  30.970         3  northwest  10600.54830          0
# 1334   18  female  31.920         0  northeast   2205.98080          0
# 1335   18  female  36.850         0  southeast   1629.83350          0
# 1336   21  female  25.800         0  southwest   2007.94500          0
# 1337   61  female  29.070         0  northwest  29141.36030          1
#
# [1338 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df["Yosh"]=le.fit_transform(df["age"])
df
# Out:
#       age     sex     bmi  children smoker     region      charges  Yosh
# 0      19  female  27.900         0    yes  southwest  16884.92400     1
# 1      18    male  33.770         1     no  southeast   1725.55230     0
# 2      28    male  33.000         3     no  southeast   4449.46200    10
# 3      33    male  22.705         0     no  northwest  21984.47061    15
# 4      32    male  28.880         0     no  northwest   3866.85520    14
# ...   ...     ...     ...       ...    ...        ...          ...   ...
# 1333   50    male  30.970         3     no  northwest  10600.54830    32
# 1334   18  female  31.920         0     no  northeast   2205.98080     0
# 1335   18  female  36.850         0     no  southeast   1629.83350     0
# 1336   21  female  25.800         0     no  southwest   2007.94500     3
# 1337   61  female  29.070         0    yes  northwest  29141.36030    43
#
# [1338 rows x 8 columns]

# %%
pd.factorize(df["age"])
# Out:
# (array([ 0,  1,  2, ...,  1, 27, 35], dtype=int64),
#  Index([19, 18, 28, 33, 32, 31, 46, 37, 60, 25, 62, 23, 56, 27, 52, 30, 34, 59,
#         63, 55, 22, 26, 35, 24, 41, 38, 36, 21, 48, 40, 58, 53, 43, 64, 20, 61,
#         44, 57, 29, 45, 54, 49, 47, 51, 42, 50, 39],
#        dtype='int64'))

# %%
df["Yoshlar"]=pd.factorize(df["age"])[0]
df
# Out:
#       age     sex     bmi  children smoker     region      charges  Yosh  \
# 0      19  female  27.900         0    yes  southwest  16884.92400     1
# 1      18    male  33.770         1     no  southeast   1725.55230     0
# 2      28    male  33.000         3     no  southeast   4449.46200    10
# 3      33    male  22.705         0     no  northwest  21984.47061    15
# 4      32    male  28.880         0     no  northwest   3866.85520    14
# ...   ...     ...     ...       ...    ...        ...          ...   ...
# 1333   50    male  30.970         3     no  northwest  10600.54830    32
# 1334   18  female  31.920         0     no  northeast   2205.98080     0
# 1335   18  female  36.850         0     no  southeast   1629.83350     0
# 1336   21  female  25.800         0     no  southwest   2007.94500     3
# 1337   61  female  29.070         0    yes  northwest  29141.36030    43
#
#       Yoshlar
# 0           0
# 1           1
# 2           2
# 3           3
# ...

# %%
df["Jins"]=pd.factorize(df["sex"])[0]
df
# Out:
#       age     sex     bmi  children smoker     region      charges  Yosh  \
# 0      19  female  27.900         0    yes  southwest  16884.92400     1
# 1      18    male  33.770         1     no  southeast   1725.55230     0
# 2      28    male  33.000         3     no  southeast   4449.46200    10
# 3      33    male  22.705         0     no  northwest  21984.47061    15
# 4      32    male  28.880         0     no  northwest   3866.85520    14
# ...   ...     ...     ...       ...    ...        ...          ...   ...
# 1333   50    male  30.970         3     no  northwest  10600.54830    32
# 1334   18  female  31.920         0     no  northeast   2205.98080     0
# 1335   18  female  36.850         0     no  southeast   1629.83350     0
# 1336   21  female  25.800         0     no  southwest   2007.94500     3
# 1337   61  female  29.070         0    yes  northwest  29141.36030    43
#
#       Yoshlar  Jins
# 0           0     0
# 1           1     1
# 2           2     1
# ...

# %%
sns.histplot(df["bmi"])
# Out:
# <Axes: xlabel='bmi', ylabel='Count'>

# %%
std=df["bmi"].std()
mean=df["bmi"].mean()

# %%
std
# Out:
# 6.098186911679014

# %%
mean
# Out:
# 30.66339686098655

# %%
out=df[(df["bmi"]>mean-3*std)&(df["bmi"]<mean+3*std)]

# %%
sns.histplot(out["bmi"])
# Out:
# <Axes: xlabel='bmi', ylabel='Count'>

# %%
sns.histplot(df["bmi"])
# Out:
# <Axes: xlabel='bmi', ylabel='Count'>

# %%
quant25=df["charges"].describe()[4]
quant75=df["charges"].describe()[6]
quant25
# Out:
# C:\Users\Nurbek\AppData\Local\Temp\ipykernel_7816\3857927443.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   quant25=df["charges"].describe()[4]
# C:\Users\Nurbek\AppData\Local\Temp\ipykernel_7816\3857927443.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   quant75=df["charges"].describe()[6]
# 4740.28715

# %%
IQR=quant75-quant25
Upper_limit=quant75+IQR*3/2
Lower_limit=quant25-IQR*3/2

# %%
Upper_limit
# Out:
# 34489.350562499996

# %%
Lower_limit
# Out:
# -13109.1508975

# %%
IQR
# Out:
# 11899.625365

# %%
out2=df[(df["charges"]>Lower_limit)&(df["charges"]<Upper_limit)]

# %%
sns.histplot(out2["charges"])
# Out:
# <Axes: xlabel='charges', ylabel='Count'>

# %%
sns.histplot(df["charges"])
# Out:
# <Axes: xlabel='charges', ylabel='Count'>

# %% [markdown]
# 95 ga 5 foizli ma'lumot yuq ekan
